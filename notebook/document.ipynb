# %%
import os
from langchain_core.documents import Document
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader, TextLoader, DirectoryLoader

# %%
doc = Document(
    page_content="This is a sample document.", 
    metadata={
        "source":"exmaple.txt",
        "pages":1,
        "author":"Chux Aboaja",
        "date_created":"2025-01-01"
    }
    )
doc
# Out:
# Document(metadata={'source': 'exmaple.txt', 'pages': 1, 'author': 'Chux Aboaja', 'date_created': '2025-01-01'}, page_content='This is a sample document.')

# %%
os.makedirs("../data/text_files",exist_ok=True)

# %%
## load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/emails",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False
)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\emails\\Email_20220320_005.txt'}, page_content='\nFrom: pm@controlcutter.no\nTo: client@equinorasa.com\nDate: 2022-03-20 00:00\nSubject: Equipment Issue Report - Forties Field\n\nDear Sarah,\n\nReporting minor hydraulic pressure fluctuation on HC-1890-06\n\nNo impact to project timeline expected\n\nLooking forward to your feedback.\n\nBest regards,\nTom Hansen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20220408_021.txt'}, page_content='\nFrom: pm@controlcutter.no\nTo: client@bpnorthsea.com\nDate: 2022-04-08 00:00\nSubject: Project Status Update - Brent Field\n\nDear John,\n\nWeekly project status update for CC-2022-106\n\nCurrent progress: {progress}% complete\n\nLet me know if you have questions.\n\nBest regards,\nLars Eriksen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20220619_019.txt'}, page_content='\nFrom: safety@controlcutter.no\nTo: client@shelluk.com\nDate: 2022-06-19 00:00\nSubject: Equipment Issue Report - Snorre\n\nDear John,\n\nReporting minor hydraulic pressure fluctuation on HC-1536-05\n\nIssue detected during routine monitoring\n\nLooking forward to your feedback.\n\nBest regards,\nTom Hansen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20221118_002.txt'}, page_content='\nFrom: pm@controlcutter.no\nTo: client@bpnorthsea.com\nDate: 2022-11-18 00:00\nSubject: Client Request - Ekofisk\n\nDear Operations Manager,\n\nClient requesting additional cutting at Forties Field\n\nScope change: +3 conductors to original plan\n\nPlease confirm receipt.\n\nBest regards,\nEmma Williams\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20221120_016.txt'}, page_content='\nFrom: safety@controlcutter.no\nTo: client@bpnorthsea.com\nDate: 2022-11-20 00:00\nSubject: Client Request - Brent Field\n\nDear Project Team,\n\nClient requesting additional cutting at Ekofisk\n\nProposal amendment to follow\n\nPlease confirm receipt.\n\nBest regards,\nTom Hansen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20221209_023.txt'}, page_content='\nFrom: pm@controlcutter.no\nTo: client@bpnorthsea.com\nDate: 2022-12-09 00:00\nSubject: Project Status Update - Ekofisk\n\nDear Sarah,\n\nWeekly project status update for CC-2022-141\n\nOn track for completion {date}\n\nPlease confirm receipt.\n\nBest regards,\nSarah Mitchell\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20221225_015.txt'}, page_content='\nFrom: operations@controlcutter.no\nTo: client@equinorasa.com\nDate: 2022-12-25 00:00\nSubject: Safety Alert - Ninian Field\n\nDear John,\n\nWeather forecast shows deteriorating conditions\n\nEquipment secured, personnel safe\n\nPlease confirm receipt.\n\nBest regards,\nSarah Mitchell\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20230118_011.txt'}, page_content='\nFrom: operations@controlcutter.no\nTo: client@shelluk.com\nDate: 2023-01-18 00:00\nSubject: Equipment Issue Report - Brent Field\n\nDear Operations Manager,\n\nReporting minor hydraulic pressure fluctuation on HC-2431-01\n\nNo impact to project timeline expected\n\nPlease confirm receipt.\n\nBest regards,\nSarah Mitchell\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20230314_024.txt'}, page_content='\nFrom: pm@controlcutter.no\nTo: client@shelluk.com\nDate: 2023-03-14 00:00\nSubject: Project Status Update - Snorre\n\nDear Project Team,\n\nWeekly project status update for CC-2023-151\n\nOn track for completion {date}\n\nLet me know if you have questions.\n\nBest regards,\nTom Hansen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20230422_027.txt'}, page_content='\nFrom: safety@controlcutter.no\nTo: client@equinorasa.com\nDate: 2023-04-22 00:00\nSubject: Project Status Update - Brent Field\n\nDear Operations Manager,\n\nWeekly project status update for CC-2023-194\n\nCurrent progress: {progress}% complete\n\nLooking forward to your feedback.\n\nBest regards,\nEmma Williams\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20230424_004.txt'}, page_content='\nFrom: safety@controlcutter.no\nTo: client@equinorasa.com\nDate: 2023-04-24 00:00\nSubject: Client Request - Forties Field\n\nDear Project Team,\n\nClient requesting additional cutting at Ekofisk\n\nScope change: +3 conductors to original plan\n\nPlease confirm receipt.\n\nBest regards,\nLars Eriksen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20230424_007.txt'}, page_content='\nFrom: safety@controlcutter.no\nTo: client@shelluk.com\nDate: 2023-04-24 00:00\nSubject: Safety Alert - Forties Field\n\nDear Project Team,\n\nWeather forecast shows deteriorating conditions\n\nEquipment secured, personnel safe\n\nWill keep you updated on progress.\n\nBest regards,\nTom Hansen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20230504_022.txt'}, page_content='\nFrom: operations@controlcutter.no\nTo: client@equinorasa.com\nDate: 2023-05-04 00:00\nSubject: Equipment Issue Report - Ninian Field\n\nDear Project Team,\n\nReporting minor hydraulic pressure fluctuation on HC-2892-06\n\nIssue detected during routine monitoring\n\nPlease confirm receipt.\n\nBest regards,\nSarah Mitchell\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20230725_025.txt'}, page_content='\nFrom: operations@controlcutter.no\nTo: client@equinorasa.com\nDate: 2023-07-25 00:00\nSubject: Client Request - Statfjord\n\nDear John,\n\nClient requesting additional cutting at Snorre\n\nProposal amendment to follow\n\nPlease confirm receipt.\n\nBest regards,\nLars Eriksen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20230814_029.txt'}, page_content='\nFrom: operations@controlcutter.no\nTo: client@bpnorthsea.com\nDate: 2023-08-14 00:00\nSubject: Project Status Update - Forties Field\n\nDear Sarah,\n\nWeekly project status update for CC-2023-131\n\nWeather window looking favorable for next week\n\nWill keep you updated on progress.\n\nBest regards,\nLars Eriksen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20230831_028.txt'}, page_content='\nFrom: operations@controlcutter.no\nTo: client@shelluk.com\nDate: 2023-08-31 00:00\nSubject: Equipment Issue Report - Statfjord\n\nDear Project Team,\n\nReporting minor hydraulic pressure fluctuation on HC-2173-02\n\nMaintenance scheduled for tomorrow\n\nPlease confirm receipt.\n\nBest regards,\nEmma Williams\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20230906_006.txt'}, page_content='\nFrom: pm@controlcutter.no\nTo: client@shelluk.com\nDate: 2023-09-06 00:00\nSubject: Client Request - Ninian Field\n\nDear Project Team,\n\nClient requesting additional cutting at Statfjord\n\nClient approval needed by {date}\n\nLet me know if you have questions.\n\nBest regards,\nEmma Williams\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20231030_009.txt'}, page_content='\nFrom: safety@controlcutter.no\nTo: client@equinorasa.com\nDate: 2023-10-30 00:00\nSubject: Project Status Update - Snorre\n\nDear Operations Manager,\n\nWeekly project status update for CC-2023-142\n\nCurrent progress: {progress}% complete\n\nWill keep you updated on progress.\n\nBest regards,\nSarah Mitchell\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20231101_012.txt'}, page_content='\nFrom: pm@controlcutter.no\nTo: client@equinorasa.com\nDate: 2023-11-01 00:00\nSubject: Safety Alert - Ekofisk\n\nDear Operations Manager,\n\nWeather forecast shows deteriorating conditions\n\nRecommend postponing operations 24 hours\n\nLet me know if you have questions.\n\nBest regards,\nLars Eriksen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20231205_018.txt'}, page_content='\nFrom: operations@controlcutter.no\nTo: client@shelluk.com\nDate: 2023-12-05 00:00\nSubject: Safety Alert - Troll Field\n\nDear Project Team,\n\nWeather forecast shows deteriorating conditions\n\nEquipment secured, personnel safe\n\nWill keep you updated on progress.\n\nBest regards,\nTom Hansen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20240207_008.txt'}, page_content='\nFrom: safety@controlcutter.no\nTo: client@equinorasa.com\nDate: 2024-02-07 00:00\nSubject: Equipment Issue Report - Brent Field\n\nDear Project Team,\n\nReporting minor hydraulic pressure fluctuation on HC-2195-02\n\nMaintenance scheduled for tomorrow\n\nWill keep you updated on progress.\n\nBest regards,\nLars Eriksen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20240306_026.txt'}, page_content='\nFrom: pm@controlcutter.no\nTo: client@equinorasa.com\nDate: 2024-03-06 00:00\nSubject: Equipment Issue Report - Forties Field\n\nDear John,\n\nReporting minor hydraulic pressure fluctuation on HC-2746-05\n\nMaintenance scheduled for tomorrow\n\nLet me know if you have questions.\n\nBest regards,\nTom Hansen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20240328_014.txt'}, page_content='\nFrom: safety@controlcutter.no\nTo: client@shelluk.com\nDate: 2024-03-28 00:00\nSubject: Equipment Issue Report - Magnus Field\n\nDear John,\n\nReporting minor hydraulic pressure fluctuation on HC-1686-03\n\nMaintenance scheduled for tomorrow\n\nLooking forward to your feedback.\n\nBest regards,\nEmma Williams\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20240604_013.txt'}, page_content='\nFrom: operations@controlcutter.no\nTo: client@bpnorthsea.com\nDate: 2024-06-04 00:00\nSubject: Safety Alert - Brent Field\n\nDear Operations Manager,\n\nWeather forecast shows deteriorating conditions\n\nRecommend postponing operations 24 hours\n\nWill keep you updated on progress.\n\nBest regards,\nTom Hansen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20240828_001.txt'}, page_content='\nFrom: safety@controlcutter.no\nTo: client@shelluk.com\nDate: 2024-08-28 00:00\nSubject: Client Request - Troll Field\n\nDear Operations Manager,\n\nClient requesting additional cutting at Statfjord\n\nProposal amendment to follow\n\nWill keep you updated on progress.\n\nBest regards,\nEmma Williams\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20240830_010.txt'}, page_content='\nFrom: pm@controlcutter.no\nTo: client@bpnorthsea.com\nDate: 2024-08-30 00:00\nSubject: Project Status Update - Magnus Field\n\nDear Sarah,\n\nWeekly project status update for CC-2024-111\n\nCurrent progress: {progress}% complete\n\nWill keep you updated on progress.\n\nBest regards,\nTom Hansen\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20241030_017.txt'}, page_content='\nFrom: pm@controlcutter.no\nTo: client@shelluk.com\nDate: 2024-10-30 00:00\nSubject: Client Request - Snorre\n\nDear Sarah,\n\nClient requesting additional cutting at Ekofisk\n\nClient approval needed by {date}\n\nWill keep you updated on progress.\n\nBest regards,\nEmma Williams\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20241107_000.txt'}, page_content='\nFrom: safety@controlcutter.no\nTo: client@bpnorthsea.com\nDate: 2024-11-07 00:00\nSubject: Safety Alert - Forties Field\n\nDear John,\n\nWeather forecast shows deteriorating conditions\n\nWill resume when conditions improve\n\nWill keep you updated on progress.\n\nBest regards,\nEmma Williams\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20241115_003.txt'}, page_content='\nFrom: pm@controlcutter.no\nTo: client@shelluk.com\nDate: 2024-11-15 00:00\nSubject: Client Request - Magnus Field\n\nDear John,\n\nClient requesting additional cutting at Ninian Field\n\nScope change: +3 conductors to original plan\n\nLet me know if you have questions.\n\nBest regards,\nEmma Williams\nControl Cutter AS\n'),
#  Document(metadata={'source': '..\\data\\emails\\Email_20241230_020.txt'}, page_content='\nFrom: operations@controlcutter.no\nTo: client@equinorasa.com\nDate: 2024-12-30 00:00\nSubject: Safety Alert - Troll Field\n\nDear Sarah,\n\nWeather forecast shows deteriorating conditions\n\nWill resume when conditions improve\n\nLet me know if you have questions.\n\nBest regards,\nEmma Williams\nControl Cutter AS\n')]
